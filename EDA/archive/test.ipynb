# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
from get_prepared_data import get_settlement_price_data_cleaned
df = get_settlement_price_data_cleaned()
df.head()
# Out:
#          Date  average_settlement_price  variance_in_settlement_price  \
# 0  2021-11-03                101.509167                      3.940990
# 1  2021-11-04                101.025000                      8.447348
# 2  2021-11-05                115.624583                    109.434182
# 3  2021-11-06                108.921667                     37.255449
# 4  2021-11-07                106.220833                      2.780408
#
#    std_settlement_price  min_settlement_price  max_settlement_price  \
# 0              1.985193                 98.51                104.16
# 1              2.906432                 96.55                106.13
# 2             10.461079                101.17                128.29
# 3              6.103724                105.30                128.05
# 4              1.667456                104.41                110.35
#
#    settlement_price_range  median_settlement_price  first_settlement_price  \
# ...

# %%
from get_prepared_data import merge_prices_and_hydro

df_all = merge_prices_and_hydro()
#282503

# %%
df_all.info()
df_all.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 59558 entries, 0 to 59557
# Data columns (total 25 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   DateTime                      59558 non-null  datetime64[ns]
#  1   DeliveryStartDate             59558 non-null  datetime64[ns]
#  2   Forward Price                 59558 non-null  float64
#  3   Year                          59558 non-null  int64
#  4   Month                         59558 non-null  int64
#  5   Day                           59558 non-null  int64
#  6   Day Of Week                   59558 non-null  object
#  7   Region                        59558 non-null  object
#  8   Date                          59558 non-null  object
#  9   average_settlement_price      59558 non-null  float64
#  10  variance_in_settlement_price  59558 non-null  float64
#  11  std_settlement_price          59558 non-null  float64
# ...

# %%
df_all.notnull()
df_all.notna().sum()
# Out:
# DateTime                        59558
# DeliveryStartDate               59558
# Forward Price                   59558
# Year                            59558
# Month                           59558
# Day                             59558
# Day Of Week                     59558
# Region                          59558
# Date                            59558
# average_settlement_price        59558
# variance_in_settlement_price    59558
# std_settlement_price            59558
# min_settlement_price            59558
# max_settlement_price            59558
# settlement_price_range          59558
# median_settlement_price         59558
# first_settlement_price          59558
# last_settlement_price           59558
# count_price                     59558
# skewness_settlement_price       59558
# Inflow_N                        59558
# Inflow_NE                       59558
# Inflow_S                        59558
# Inflow_SE/CW                    59558
# Total Daily Inflow              59558
# ...

# %%
from get_prepared_data import get_data_set_and_split_to_train_and_test
X_train, X_test, y_train, y_test = get_data_set_and_split_to_train_and_test()
X_train.head()
# Out:
#         DateTime DeliveryStartDate  Forward Price  Year  Month  Day  \
# 37758 2024-05-06        2026-05-01         139.74  2024      5    6
# 3452  2022-03-04        2023-04-01         217.50  2022      3    4
# 57610 2024-09-05        2033-05-01         139.70  2024      9    5
# 37669 2024-05-05        2025-09-01         124.01  2024      5    5
# 38752 2024-05-18        2028-12-01         139.74  2024      5   18
#
#       Day Of Week Region        Date  average_settlement_price  ...  \
# 37758      Monday  SE/CW  2024-05-06                 61.070000  ...
# 3452       Friday  SE/CW  2022-03-04                 55.700000  ...
# 57610    Thursday  SE/CW  2024-09-05                273.617917  ...
# 37669      Sunday  SE/CW  2024-05-05                 61.070000  ...
# 38752    Saturday  SE/CW  2024-05-18                 61.070000  ...
#
#        median_settlement_price  first_settlement_price  last_settlement_price  \
# ...

# %%
y_train.info()
# Out:
# <class 'pandas.core.series.Series'>
# Int64Index: 44668 entries, 37758 to 56422
# Series name: Forward Price
# Non-Null Count  Dtype
# --------------  -----
# 44668 non-null  float64
# dtypes: float64(1)
# memory usage: 697.9 KB
