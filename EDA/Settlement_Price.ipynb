# %%
import pandas as pd
import numpy as np
import os
import sys
import matplotlib.pyplot as plt
import seaborn as sns

#Path
try:
    current_dir = os.path.dirname(os.path.abspath(__file__))
except NameError:
    current_dir = os.getcwd()
parent_dir = os.path.dirname(current_dir)
xdrive_path = os.path.join(parent_dir, 'xdrive')
sys.path.append(xdrive_path)

pipeline_path = os.path.join(parent_dir, 'Pipeline')
sys.path.append(pipeline_path)

# Now you can import your module from xdrive
import get_files_from_xdrive as gxdrive

# %%
forward_price  = gxdrive.read_file_from_xdrive_as_df('Forward_Price_Cleaned.csv')
df_all = gxdrive.read_file_from_xdrive_as_df('Prepared_Dataset_left_joint.csv')
settlement_price = gxdrive.read_file_from_xdrive_as_df('Settlement_Price_Cleaned.csv')

# %%
settlement_price
# Out:
#         DateTime  Average_Settlement_Price_SE/CW(MWh)  \
# 0     2001-06-30                           684.000000
# 1     2001-07-07                           684.000000
# 2     2001-07-14                           684.000000
# 3     2001-07-21                           684.000000
# 4     2001-07-28                           684.000000
# ...          ...                                  ...
# 2458  2024-11-09                            61.083750
# 2459  2024-11-10                            61.252500
# 2460  2024-11-11                           125.509583
# 2461  2024-11-12                           166.695833
# 2462  2024-11-13                            65.730833
#
#       Standard_Deviation_Settlement_Price_SE(MWh)  \
# 0                                        0.000000
# 1                                        0.000000
# 2                                        0.000000
# 3                                        0.000000
# 4                                        0.000000
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

    
    # Create a plot for this year showing different regions on the same graph
plt.figure(figsize=(10, 6))
    
    # Use seaborn's lineplot with 'hue' to differentiate regions
sns.lineplot(data=settlement_price, x='DateTime', y='Average_Settlement_Price_SE/CW(MWh)')
    
    # Customize the plot
plt.title(f'Average Settlement Price (MWh)')
plt.xlabel('Day of Year')
plt.grid(True)
    
    # Show the plot
plt.show()

# %%
# Assuming the dataset represents a larger dataset, we will visualize trends based on the provided columns.
# Settlement price trends and variability visualizations.

# Plot the average settlement price over time with min-max range
plt.figure(figsize=(14, 7))
sns.lineplot(
    data=settlement_price,
    x="DateTime",
    y="Average_Settlement_Price_SE/CW(MWh)",
    marker="o",
    label="Average Settlement Price"
)

plt.title("Settlement Price Trends Over Time", fontsize=16)
plt.xlabel("Date", fontsize=12)
plt.ylabel("Settlement Price (MWh)", fontsize=12)
plt.legend()
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()
