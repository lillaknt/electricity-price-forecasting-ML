# %% [markdown]
# ## This is a notebook for Table X - LSTM Performance with Different Parameters

# %%
from sklearn.model_selection import train_test_split
import pandas as pd
import os
import sys
from sklearn.model_selection import TimeSeriesSplit
from sklearn.preprocessing import StandardScaler, MinMaxScaler
# Get the directory of the current script
try:
    # This will work if the script is being run as a file
    current_dir = os.path.dirname(os.path.abspath(__file__))
except NameError:
    # Use the current working directory if __file__ is not defined
    current_dir = os.getcwd()
# Move up one directory level from EDA to the parent directory
parent_dir = os.path.dirname(current_dir)
# Construct the path to the xdrive folder
xdrive_path = os.path.join(parent_dir, 'xdrive')
# Add the xdrive path to sys.path
sys.path.append(xdrive_path)

featureeng_path = os.path.join(parent_dir, 'Feature Engineering')
# Add the xdrive path to sys.path
sys.path.append(featureeng_path)

# Construct the path to the xdrive folder
xdrive_path = os.path.join(parent_dir, 'Pipeline')
# Add the xdrive path to sys.path
sys.path.append(xdrive_path)
from build_a_pipeline import build_pipeline
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Flatten, Dropout
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.optimizers import Adam
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Flatten, Dropout
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import TimeDistributed, Dense
from build_a_pipeline import build_pipeline_P0_foward_price
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Flatten, Dropout
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import TimeDistributed, Dense
from sklearn.metrics import r2_score
import os
import random
import numpy as np
import tensorflow as tf

seed_value = 42
os.environ['PYTHONHASHSEED'] = str(seed_value)
random.seed(seed_value)
np.random.seed(seed_value)
tf.random.set_seed(seed_value)
os.environ['TF_DETERMINISTIC_OPS'] = '1'
os.environ['TF_CUDNN_DETERMINISTIC'] = '1'

# %% [markdown]
# ## MODEL 3
# - Multiple multivariate layers

# %% [markdown]
# ## P0 Prediction

# %%
model_performance = []
percentage_of_outliers_removed = 0.01

x_train, x_val, X_test, y_train, y_val, y_test = build_pipeline_P0_foward_price(drop_features=True, 
                                                                                remove_outliers = True, 
                                                                                train_size = 0.75, 
                                                                                val_size = 0.15,
                                                                                percentage_of_outliers=percentage_of_outliers_removed) #drop_features = False
datetime_index = X_test.index
feature_names_P0 = X_test.columns
x_train = x_train.to_numpy()
x_val = x_val.to_numpy()
X_test = X_test.to_numpy()

# merge train and validation
x_train_combined = np.vstack([x_train, x_val])  # Combine x_train and x_val
y_train_combined = np.concatenate([y_train, y_val])  # Combine y_train and y_val
y_train = y_train_combined

#reshape
x_train = x_train_combined.reshape(x_train_combined.shape[0], 1, x_train_combined.shape[1])  # [samples, time_steps=1, features]
# Test data
x_test = X_test.reshape(X_test.shape[0], 1, X_test.shape[1])

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Flatten, Dropout
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import TimeDistributed, Dense

# Build the LSTM multivariate_lstm
multivariate_lstm = Sequential([
    LSTM(200, input_shape=(x_train.shape[1], x_train.shape[2]), return_sequences=True),
    TimeDistributed(Dense(200, activation='selu')), 
    Dropout(0.3),
    TimeDistributed(Dense(100, activation='selu')), 
    Dropout(0.3),
    TimeDistributed(Dense(50, activation='selu')), 
    Dropout(0.3),
    Flatten(),
    Dense(1)  # Output layer
])

# ModelCheckpoint to save the best multivariate_lstm based on validation loss
model_checkpoint = ModelCheckpoint('multivariate_lstm.keras', monitor='val_loss', save_best_only=True)

# EarlyStopping to prevent overfitting
early_stopping = EarlyStopping(monitor='val_loss', patience=50, restore_best_weights=True)

# Optimizer with adjusted learning rate
optimizer = Adam(learning_rate=6e-3, amsgrad=True)

# Loss function and metric
loss = tf.keras.losses.MeanSquaredError()
metric = [tf.keras.metrics.RootMeanSquaredError()]

# Compile the multivariate_lstm
multivariate_lstm.compile(loss=loss, optimizer=optimizer, metrics=metric)

# Train the multivariate_lstm (make sure you pass both x_val and y_val)
history = multivariate_lstm.fit(x_train, y_train, epochs=120,
                                validation_data=(x_test, y_test),
                                callbacks=[early_stopping, model_checkpoint])

# Optionally, print the final RMSE
train_rmse = history.history['root_mean_squared_error'][-1]
val_rmse = history.history['val_root_mean_squared_error'][-1]
print(f"Final train RMSE: {train_rmse}")
print(f"Final test RMSE: {val_rmse}")

from tensorflow.keras.models import load_model
#best_model = load_model('multivariate_lstm.keras')
y_pred = multivariate_lstm.predict(x_test)
y_pred = y_pred.flatten()  # or y_pred.squeeze() if necessary
r_squared = r2_score(y_test, y_pred)
print(f"R-squared: {r_squared}")
model_performance.append({
    'Model': 'Model 3' ,
    'Target': 'P0',
    'Percentage of Outliers Removed': percentage_of_outliers_removed,
    'Train RMSE': train_rmse,
    'Test RMSE': val_rmse,
    'R2': r_squared
})
# Out:
# Epoch 1/120
# C:\Users\veron\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - loss: 12578.0957 - root_mean_squared_error: 111.8091 - val_loss: 25953.7051 - val_root_mean_squared_error: 161.1015
# Epoch 2/120
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1814.9174 - root_mean_squared_error: 42.3327 - val_loss: 18567.7793 - val_root_mean_squared_error: 136.2636
# Epoch 3/120
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1214.3196 - root_mean_squared_error: 34.7711 - val_loss: 13750.4277 - val_root_mean_squared_error: 117.2622
# Epoch 4/120
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1831.7009 - root_mean_squared_error: 42.6698 - val_loss: 21366.9297 - val_root_mean_squared_error: 146.1743
# Epoch 5/120
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1537.5758 - root_mean_squared_error: 39.1410 - val_loss: 22093.1348 - val_root_mean_squared_error: 148.6376
# Epoch 6/120
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1257.9952 - root_mean_squared_error: 35.2344 - val_loss: 21278.3477 - val_root_mean_squared_error: 145.8710
# Epoch 7/120
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1996.8873 - root_mean_squared_error: 44.5224 - val_loss: 18969.8770 - val_root_mean_squared_error: 137.7312
# Epoch 8/120
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1001.5369 - root_mean_squared_error: 31.3687 - val_loss: 15164.2363 - val_root_mean_squared_error: 123.1432
# Epoch 9/120
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1145.8191 - root_mean_squared_error: 33.6920 - val_loss: 17387.1133 - val_root_mean_squared_error: 131.8602
# Epoch 10/120
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 843.3941 - root_mean_squared_error: 27.9104 - val_loss: 14166.5635 - val_root_mean_squared_error: 119.0234
# Epoch 11/120
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1247.8982 - root_mean_squared_error: 35.1882 - val_loss: 14309.1133 - val_root_mean_squared_error: 119.6207
# Epoch 12/120
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 999.4341 - root_mean_squared_error: 31.4356 - val_loss: 10364.8076 - val_root_mean_squared_error: 101.8077
# Epoch 13/120
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 654.8875 - root_mean_squared_error: 25.2339 - val_loss: 13219.5674 - val_root_mean_squared_error: 114.9764
# Epoch 14/120
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 846.5829 - root_mean_squared_error: 29.0145 - val_loss: 13625.1709 - val_root_mean_squared_error: 116.7269
# Epoch 15/120
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 982.5947 - root_mean_squared_error: 30.9703 - val_loss: 10842.2285 - val_root_mean_squared_error: 104.1260
# Epoch 16/120
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1094.8374 - root_mean_squared_error: 32.9783 - val_loss: 11317.7158 - val_root_mean_squared_error: 106.3848
# Epoch 17/120
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 833.6805 - root_mean_squared_error: 28.5043 - val_loss: 15497.8057 - val_root_mean_squared_error: 124.4902
# Epoch 18/120
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 624.6524 - root_mean_squared_error: 24.5258 - val_loss: 9519.6953 - val_root_mean_squared_error: 97.5689
# Epoch 19/120
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1029.1151 - root_mean_squared_error: 31.7264 - val_loss: 10655.8467 - val_root_mean_squared_error: 103.2272
# Epoch 20/120
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 981.5980 - root_mean_squared_error: 31.0320 - val_loss: 9732.8975 - val_root_mean_squared_error: 98.6554
# Epoch 21/120
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 669.9569 - root_mean_squared_error: 25.4766 - val_loss: 6467.6006 - val_root_mean_squared_error: 80.4214
# Epoch 22/120
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 692.4517 - root_mean_squared_error: 25.7041 - val_loss: 7161.4971 - val_root_mean_squared_error: 84.6256
# Epoch 23/120
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 762.9287 - root_mean_squared_error: 27.4492 - val_loss: 10092.3633 - val_root_mean_squared_error: 100.4608
# Epoch 24/120
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 723.1242 - root_mean_squared_error: 26.3506 - val_loss: 16907.2324 - val_root_mean_squared_error: 130.0278
# Epoch 25/120
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 601.7579 - root_mean_squared_error: 24.4030 - val_loss: 9027.5527 - val_root_mean_squared_error: 95.0134
# Epoch 26/120
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 691.2027 - root_mean_squared_error: 25.5959 - val_loss: 9985.0107 - val_root_mean_squared_error: 99.9250
# Epoch 27/120
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1381.0876 - root_mean_squared_error: 35.6385 - val_loss: 6509.5918 - val_root_mean_squared_error: 80.6820
# Epoch 28/120
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 843.8504 - root_mean_squared_error: 28.8556 - val_loss: 7054.0947 - val_root_mean_squared_error: 83.9887
# Epoch 29/120
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 692.6406 - root_mean_squared_error: 26.2931 - val_loss: 8107.8008 - val_root_mean_squared_error: 90.0433
# Epoch 30/120
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 715.2792 - root_mean_squared_error: 26.4616 - val_loss: 7420.0737 - val_root_mean_squared_error: 86.1398
# Epoch 31/120
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 638.4667 - root_mean_squared_error: 25.0945 - val_loss: 9297.6768 - val_root_mean_squared_error: 96.4245
# Epoch 32/120
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 516.0576 - root_mean_squared_error: 22.5753 - val_loss: 7771.7095 - val_root_mean_squared_error: 88.1573
# Epoch 33/120
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 529.4828 - root_mean_squared_error: 22.6730 - val_loss: 9488.1348 - val_root_mean_squared_error: 97.4071
# Epoch 34/120
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 455.5555 - root_mean_squared_error: 21.0516 - val_loss: 8181.8442 - val_root_mean_squared_error: 90.4535
# Epoch 35/120
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 612.5021 - root_mean_squared_error: 24.2004 - val_loss: 7738.8516 - val_root_mean_squared_error: 87.9707
# Epoch 36/120
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 795.4082 - root_mean_squared_error: 27.9667 - val_loss: 9387.2383 - val_root_mean_squared_error: 96.8878
# Epoch 37/120
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 672.1114 - root_mean_squared_error: 25.5070 - val_loss: 9352.3164 - val_root_mean_squared_error: 96.7074
# Epoch 38/120
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 742.8265 - root_mean_squared_error: 27.1196 - val_loss: 6640.5737 - val_root_mean_squared_error: 81.4897
# Epoch 39/120
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 616.3289 - root_mean_squared_error: 24.1900 - val_loss: 6487.2471 - val_root_mean_squared_error: 80.5434
# Epoch 40/120
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 721.2089 - root_mean_squared_error: 26.7349 - val_loss: 8007.4932 - val_root_mean_squared_error: 89.4846
# Epoch 41/120
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 849.3156 - root_mean_squared_error: 28.6397 - val_loss: 6441.4839 - val_root_mean_squared_error: 80.2589
# Epoch 42/120
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 776.0568 - root_mean_squared_error: 27.2972 - val_loss: 7135.2554 - val_root_mean_squared_error: 84.4704
# Epoch 43/120
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 868.0676 - root_mean_squared_error: 29.3541 - val_loss: 8226.9043 - val_root_mean_squared_error: 90.7023
# Epoch 44/120
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 513.3741 - root_mean_squared_error: 22.5253 - val_loss: 7987.3223 - val_root_mean_squared_error: 89.3718
# Epoch 45/120
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 692.9842 - root_mean_squared_error: 26.2693 - val_loss: 9123.1143 - val_root_mean_squared_error: 95.5150
# Epoch 46/120
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 814.1513 - root_mean_squared_error: 27.7018 - val_loss: 7081.0264 - val_root_mean_squared_error: 84.1488
# Epoch 47/120
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 671.1622 - root_mean_squared_error: 25.7331 - val_loss: 9485.0996 - val_root_mean_squared_error: 97.3915
# Epoch 48/120
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 699.4233 - root_mean_squared_error: 26.3387 - val_loss: 8728.1914 - val_root_mean_squared_error: 93.4248
# Epoch 49/120
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 635.5115 - root_mean_squared_error: 24.8566 - val_loss: 7039.0708 - val_root_mean_squared_error: 83.8992
# Epoch 50/120
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 735.7740 - root_mean_squared_error: 26.4313 - val_loss: 6292.0259 - val_root_mean_squared_error: 79.3223
# Epoch 51/120
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 596.3098 - root_mean_squared_error: 24.2212 - val_loss: 6549.0454 - val_root_mean_squared_error: 80.9262
# Epoch 52/120
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 812.2442 - root_mean_squared_error: 28.1416 - val_loss: 13460.0381 - val_root_mean_squared_error: 116.0174
# Epoch 53/120
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 842.4601 - root_mean_squared_error: 28.9336 - val_loss: 8881.5742 - val_root_mean_squared_error: 94.2421
# Epoch 54/120
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 776.7628 - root_mean_squared_error: 27.7849 - val_loss: 7469.0454 - val_root_mean_squared_error: 86.4236
# Epoch 55/120
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 515.8364 - root_mean_squared_error: 22.3417 - val_loss: 7411.6914 - val_root_mean_squared_error: 86.0912
# Epoch 56/120
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 592.8989 - root_mean_squared_error: 24.0113 - val_loss: 6586.8228 - val_root_mean_squared_error: 81.1592
# Epoch 57/120
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 559.7808 - root_mean_squared_error: 23.2590 - val_loss: 6453.3447 - val_root_mean_squared_error: 80.3327
# Epoch 58/120
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 612.7923 - root_mean_squared_error: 24.4444 - val_loss: 7180.3530 - val_root_mean_squared_error: 84.7370
# Epoch 59/120
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 925.2696 - root_mean_squared_error: 29.6607 - val_loss: 7947.7241 - val_root_mean_squared_error: 89.1500
# Epoch 60/120
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1053.9624 - root_mean_squared_error: 31.7847 - val_loss: 11953.4297 - val_root_mean_squared_error: 109.3317
# Epoch 61/120
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 595.6595 - root_mean_squared_error: 24.3443 - val_loss: 6759.6807 - val_root_mean_squared_error: 82.2173
# Epoch 62/120
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1373.0094 - root_mean_squared_error: 36.6274 - val_loss: 12054.5371 - val_root_mean_squared_error: 109.7932
# Epoch 63/120
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 863.3123 - root_mean_squared_error: 29.0890 - val_loss: 6715.9043 - val_root_mean_squared_error: 81.9506
# Epoch 64/120
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 603.2208 - root_mean_squared_error: 23.9753 - val_loss: 5967.2231 - val_root_mean_squared_error: 77.2478
# Epoch 65/120
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 557.4711 - root_mean_squared_error: 23.3742 - val_loss: 7471.6289 - val_root_mean_squared_error: 86.4386
# Epoch 66/120
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 474.5450 - root_mean_squared_error: 21.1732 - val_loss: 7263.9058 - val_root_mean_squared_error: 85.2286
# Epoch 67/120
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 675.4482 - root_mean_squared_error: 25.8670 - val_loss: 9412.6416 - val_root_mean_squared_error: 97.0188
# Epoch 68/120
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 788.0969 - root_mean_squared_error: 27.3427 - val_loss: 7602.1060 - val_root_mean_squared_error: 87.1901
# Epoch 69/120
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 487.9336 - root_mean_squared_error: 21.6029 - val_loss: 7978.8516 - val_root_mean_squared_error: 89.3244
# Epoch 70/120
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 520.7065 - root_mean_squared_error: 22.3316 - val_loss: 8133.5537 - val_root_mean_squared_error: 90.1862
# Epoch 71/120
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 440.5279 - root_mean_squared_error: 20.8974 - val_loss: 8355.9131 - val_root_mean_squared_error: 91.4107
# Epoch 72/120
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 694.3459 - root_mean_squared_error: 25.9959 - val_loss: 8935.1270 - val_root_mean_squared_error: 94.5258
# Epoch 73/120
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 790.0786 - root_mean_squared_error: 27.8782 - val_loss: 8327.7363 - val_root_mean_squared_error: 91.2564
# Epoch 74/120
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 754.4955 - root_mean_squared_error: 27.2310 - val_loss: 6858.1411 - val_root_mean_squared_error: 82.8139
# Epoch 75/120
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 493.4520 - root_mean_squared_error: 22.1200 - val_loss: 6539.8462 - val_root_mean_squared_error: 80.8693
# Epoch 76/120
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 514.6676 - root_mean_squared_error: 22.6241 - val_loss: 22386.6914 - val_root_mean_squared_error: 149.6218
# Epoch 77/120
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 629.2562 - root_mean_squared_error: 24.8732 - val_loss: 19668.1211 - val_root_mean_squared_error: 140.2431
# Epoch 78/120
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 567.9525 - root_mean_squared_error: 23.4911 - val_loss: 14709.2646 - val_root_mean_squared_error: 121.2818
# Epoch 79/120
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 670.5198 - root_mean_squared_error: 25.2037 - val_loss: 12574.4248 - val_root_mean_squared_error: 112.1357
# Epoch 80/120
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 931.8276 - root_mean_squared_error: 30.0770 - val_loss: 9707.9883 - val_root_mean_squared_error: 98.5291
# Epoch 81/120
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 595.0672 - root_mean_squared_error: 24.2772 - val_loss: 8200.5264 - val_root_mean_squared_error: 90.5568
# Epoch 82/120
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 563.2524 - root_mean_squared_error: 23.5651 - val_loss: 10075.9629 - val_root_mean_squared_error: 100.3791
# Epoch 83/120
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 797.8879 - root_mean_squared_error: 28.0751 - val_loss: 9831.9863 - val_root_mean_squared_error: 99.1564
# Epoch 84/120
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 751.6932 - root_mean_squared_error: 27.1130 - val_loss: 6570.1030 - val_root_mean_squared_error: 81.0562
# Epoch 85/120
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 695.6895 - root_mean_squared_error: 26.2173 - val_loss: 8446.8643 - val_root_mean_squared_error: 91.9068
# Epoch 86/120
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 612.2176 - root_mean_squared_error: 23.9666 - val_loss: 8822.1064 - val_root_mean_squared_error: 93.9261
# Epoch 87/120
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 490.4141 - root_mean_squared_error: 21.9985 - val_loss: 8398.6084 - val_root_mean_squared_error: 91.6439
# Epoch 88/120
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 564.4354 - root_mean_squared_error: 23.5027 - val_loss: 7047.8921 - val_root_mean_squared_error: 83.9517
# Epoch 89/120
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 584.4982 - root_mean_squared_error: 23.8802 - val_loss: 6022.7749 - val_root_mean_squared_error: 77.6065
# Epoch 90/120
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 507.8456 - root_mean_squared_error: 22.2459 - val_loss: 12792.6191 - val_root_mean_squared_error: 113.1045
# Epoch 91/120
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 491.8354 - root_mean_squared_error: 22.0773 - val_loss: 7917.7090 - val_root_mean_squared_error: 88.9815
# Epoch 92/120
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 509.7623 - root_mean_squared_error: 22.5216 - val_loss: 11090.2891 - val_root_mean_squared_error: 105.3104
# Epoch 93/120
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 611.6463 - root_mean_squared_error: 24.4746 - val_loss: 15492.5586 - val_root_mean_squared_error: 124.4691
# Epoch 94/120
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 613.4085 - root_mean_squared_error: 24.2946 - val_loss: 9816.9248 - val_root_mean_squared_error: 99.0804
# Epoch 95/120
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 687.3080 - root_mean_squared_error: 25.9217 - val_loss: 13567.8262 - val_root_mean_squared_error: 116.4810
# Epoch 96/120
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 451.8406 - root_mean_squared_error: 21.0292 - val_loss: 9798.0850 - val_root_mean_squared_error: 98.9853
# Epoch 97/120
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 931.5688 - root_mean_squared_error: 30.2209 - val_loss: 8584.5068 - val_root_mean_squared_error: 92.6526
# Epoch 98/120
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 462.0987 - root_mean_squared_error: 21.3483 - val_loss: 12691.5176 - val_root_mean_squared_error: 112.6566
# Epoch 99/120
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 483.2487 - root_mean_squared_error: 21.8249 - val_loss: 7200.6235 - val_root_mean_squared_error: 84.8565
# Epoch 100/120
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 542.0680 - root_mean_squared_error: 23.0424 - val_loss: 9541.9521 - val_root_mean_squared_error: 97.6829
# Epoch 101/120
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 674.2565 - root_mean_squared_error: 25.5854 - val_loss: 7506.2368 - val_root_mean_squared_error: 86.6385
# Epoch 102/120
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 447.6086 - root_mean_squared_error: 21.0701 - val_loss: 7967.4824 - val_root_mean_squared_error: 89.2608
# Epoch 103/120
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 354.1316 - root_mean_squared_error: 18.5780 - val_loss: 7543.9624 - val_root_mean_squared_error: 86.8560
# Epoch 104/120
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 615.8054 - root_mean_squared_error: 24.5879 - val_loss: 6735.8970 - val_root_mean_squared_error: 82.0725
# Epoch 105/120
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 835.9106 - root_mean_squared_error: 28.7934 - val_loss: 19901.0762 - val_root_mean_squared_error: 141.0712
# Epoch 106/120
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 727.8900 - root_mean_squared_error: 26.8292 - val_loss: 14095.4102 - val_root_mean_squared_error: 118.7241
# Epoch 107/120
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 599.7111 - root_mean_squared_error: 24.2791 - val_loss: 12982.9717 - val_root_mean_squared_error: 113.9428
# Epoch 108/120
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 440.3703 - root_mean_squared_error: 20.7043 - val_loss: 10270.2070 - val_root_mean_squared_error: 101.3420
# Epoch 109/120
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 574.1777 - root_mean_squared_error: 23.6593 - val_loss: 11141.2412 - val_root_mean_squared_error: 105.5521
# Epoch 110/120
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 733.5699 - root_mean_squared_error: 26.9744 - val_loss: 10788.1533 - val_root_mean_squared_error: 103.8660
# Epoch 111/120
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 510.9067 - root_mean_squared_error: 21.9262 - val_loss: 10753.9980 - val_root_mean_squared_error: 103.7015
# Epoch 112/120
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 561.5024 - root_mean_squared_error: 23.6818 - val_loss: 7325.5942 - val_root_mean_squared_error: 85.5897
# Epoch 113/120
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 386.2696 - root_mean_squared_error: 19.4353 - val_loss: 6718.8848 - val_root_mean_squared_error: 81.9688
# Epoch 114/120
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 650.2763 - root_mean_squared_error: 25.2714 - val_loss: 11069.8496 - val_root_mean_squared_error: 105.2134
# Final train RMSE: 29.093814849853516
# Final test RMSE: 105.2133560180664
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# R-squared: 0.6429044905865849

# %%
import tensorflow as tf
import matplotlib.pyplot as plt

# Define a function to compute gradients
def compute_gradients(input_data, model, target_index=0):
    input_tensor = tf.convert_to_tensor(input_data)
    with tf.GradientTape() as tape:
        tape.watch(input_tensor)
        predictions = model(input_tensor)
        target = predictions[:, target_index]  # Target the specific output
    gradients = tape.gradient(target, input_tensor)
    return gradients.numpy()

# Compute gradients for your test data
grads = compute_gradients(x_test, multivariate_lstm)


# Assuming `feature_names` is a list of column names corresponding to your features
# Example: feature_names = ["Feature1", "Feature2", ..., "FeatureN"]
feature_importance = np.sum(np.abs(grads), axis=1).mean(axis=0)  # Shape: (features,)

# Bar plot for feature importance with feature names
plt.figure(figsize=(12, 6))
plt.bar(feature_names_P0, feature_importance)
plt.xlabel('Features')
plt.ylabel('Gradient Magnitude (Aggregated)')
plt.title('Feature Importance for Model 3 (P0) Based on Gradients')
plt.xticks(rotation=45, ha='right')  # Rotate feature names for better readability
plt.tight_layout()  # Adjust layout to prevent overlap
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

y_pred = y_pred.flatten()
predictions_df = pd.DataFrame(y_pred, index=datetime_index, columns=['Predicted'])
y_test_df = pd.DataFrame(y_test, index=datetime_index, columns=['Actual'])
predictions_df = predictions_df.sort_index()
y_test_df = y_test_df.sort_index()

# Plotting y_actual vs y_pred
plt.figure(figsize=(12, 6))
plt.plot(datetime_index, y_test, label='Actual', marker='o')
plt.plot(y_test_df.index, predictions_df['Predicted'], label='Predicted', marker='x')
plt.title('Actual vs Predicted Values LSTM Model 3 on TEST - P0 Prediction')
plt.xlabel('DateTime')
plt.ylabel('Values')

# Rotate the x-axis labels for better visibility
plt.xticks(rotation=45)
plt.legend()
plt.grid()
plt.tight_layout()
plt.show()

# %% [markdown]
# ### P1 Prediction

# %%
# train_size = 0.75, val_size = 0.15,
x_train, x_val, X_test, y_train, y_val, y_test = build_pipeline_P0_foward_price(drop_features=True, 
                                                                                remove_outliers = True, 
                                                                                target_column = 'P1',
                                                                                train_size = 0.75, 
                                                                                val_size = 0.15,
                                                                                percentage_of_outliers=percentage_of_outliers_removed) #drop_features = False

datetime_index = X_test.index
feature_names_P1 = X_test.columns
x_train = x_train.to_numpy()
x_val = x_val.to_numpy()
X_test = X_test.to_numpy()

# merge train and validation
x_train_combined = np.vstack([x_train, x_val])  # Combine x_train and x_val
y_train_combined = np.concatenate([y_train, y_val])  # Combine y_train and y_val
y_train = y_train_combined

#reshape
x_train = x_train_combined.reshape(x_train_combined.shape[0], 1, x_train_combined.shape[1])  # [samples, time_steps=1, features]
# Test data
x_test = X_test.reshape(X_test.shape[0], 1, X_test.shape[1])

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Flatten, Dropout
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import TimeDistributed, Dense

# Build the LSTM multivariate_lstm
multivariate_lstm = Sequential([
    LSTM(250, input_shape=(x_train.shape[1], x_train.shape[2]), return_sequences=True),
    TimeDistributed(Dense(200, activation='selu')), 
    Dropout(0.3),
    TimeDistributed(Dense(100, activation='selu')), 
    Dropout(0.3),
    TimeDistributed(Dense(50, activation='selu')), 
    Dropout(0.3),
    Flatten(),
    Dense(1)  # Output layer
])

# ModelCheckpoint to save the best multivariate_lstm based on validation loss
model_checkpoint = ModelCheckpoint('multivariate_lstm.keras', monitor='val_loss', save_best_only=True)

# EarlyStopping to prevent overfitting
early_stopping = EarlyStopping(monitor='val_loss', patience=50, restore_best_weights=True)

# Optimizer with adjusted learning rate
optimizer = Adam(learning_rate=6e-3, amsgrad=True)
#optimizer = Adam(learning_rate=1e-2, amsgrad=True)

# Loss function and metric
loss = tf.keras.losses.MeanSquaredError()
metric = [tf.keras.metrics.RootMeanSquaredError()]

# Compile the multivariate_lstm
multivariate_lstm.compile(loss=loss, optimizer=optimizer, metrics=metric)

# Train the multivariate_lstm (make sure you pass both x_val and y_val)
history = multivariate_lstm.fit(x_train, y_train, epochs=120,
                                validation_data=(x_test, y_test),
                                callbacks=[early_stopping, model_checkpoint])

# Optionally, print the final RMSE
train_rmse = history.history['root_mean_squared_error'][-1]
val_rmse = history.history['val_root_mean_squared_error'][-1]
print(f"Final train RMSE: {train_rmse}")
print(f"Final validation RMSE: {val_rmse}")


from tensorflow.keras.models import load_model
#best_model = load_model('multivariate_lstm.keras')
y_pred = multivariate_lstm.predict(x_test)
y_pred = y_pred.flatten()  # or y_pred.squeeze() if necessary
r_squared = r2_score(y_test, y_pred)
print(f"R-squared: {r_squared}")
model_performance.append({
    'Model': 'Model 3' ,
    'Target': 'P1',
    'Percentage of Outliers Removed': percentage_of_outliers_removed,
    'Train RMSE': train_rmse,
    'Test RMSE': val_rmse,
    'R2': r_squared
})
# Out:
# Epoch 1/120
# C:\Users\veron\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 17749.0352 - root_mean_squared_error: 132.0987 - val_loss: 37126.2930 - val_root_mean_squared_error: 192.6818
# Epoch 2/120
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2691.6511 - root_mean_squared_error: 51.8324 - val_loss: 27122.5469 - val_root_mean_squared_error: 164.6892
# Epoch 3/120
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2399.1147 - root_mean_squared_error: 48.6156 - val_loss: 22249.0625 - val_root_mean_squared_error: 149.1612
# Epoch 4/120
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1478.1143 - root_mean_squared_error: 38.1727 - val_loss: 25259.9766 - val_root_mean_squared_error: 158.9339
# Epoch 5/120
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1718.6279 - root_mean_squared_error: 41.2732 - val_loss: 19351.0391 - val_root_mean_squared_error: 139.1080
# Epoch 6/120
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1753.1880 - root_mean_squared_error: 41.6245 - val_loss: 24227.6465 - val_root_mean_squared_error: 155.6523
# Epoch 7/120
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3450.4292 - root_mean_squared_error: 57.9796 - val_loss: 17344.9844 - val_root_mean_squared_error: 131.7004
# Epoch 8/120
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1767.9382 - root_mean_squared_error: 41.9534 - val_loss: 17751.1289 - val_root_mean_squared_error: 133.2334
# Epoch 9/120
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1791.3718 - root_mean_squared_error: 41.9078 - val_loss: 20014.1270 - val_root_mean_squared_error: 141.4713
# Epoch 10/120
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 986.2560 - root_mean_squared_error: 31.2894 - val_loss: 20900.1504 - val_root_mean_squared_error: 144.5688
# Epoch 11/120
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1719.5171 - root_mean_squared_error: 41.3801 - val_loss: 19409.7891 - val_root_mean_squared_error: 139.3190
# Epoch 12/120
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1886.2406 - root_mean_squared_error: 43.2504 - val_loss: 19504.6367 - val_root_mean_squared_error: 139.6590
# Epoch 13/120
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1741.5929 - root_mean_squared_error: 41.6054 - val_loss: 19199.7910 - val_root_mean_squared_error: 138.5633
# Epoch 14/120
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1284.1682 - root_mean_squared_error: 35.6960 - val_loss: 22503.9590 - val_root_mean_squared_error: 150.0132
# Epoch 15/120
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1013.5543 - root_mean_squared_error: 31.7198 - val_loss: 19358.8555 - val_root_mean_squared_error: 139.1361
# Epoch 16/120
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1150.0619 - root_mean_squared_error: 33.8004 - val_loss: 14509.5605 - val_root_mean_squared_error: 120.4556
# Epoch 17/120
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 984.7622 - root_mean_squared_error: 31.2506 - val_loss: 16556.5078 - val_root_mean_squared_error: 128.6721
# Epoch 18/120
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1263.1154 - root_mean_squared_error: 35.4337 - val_loss: 15221.6494 - val_root_mean_squared_error: 123.3760
# Epoch 19/120
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1974.5867 - root_mean_squared_error: 43.4906 - val_loss: 20431.8359 - val_root_mean_squared_error: 142.9400
# Epoch 20/120
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1563.3716 - root_mean_squared_error: 39.4301 - val_loss: 25199.0605 - val_root_mean_squared_error: 158.7421
# Epoch 21/120
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 882.0694 - root_mean_squared_error: 29.5184 - val_loss: 13756.0762 - val_root_mean_squared_error: 117.2863
# Epoch 22/120
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1231.1807 - root_mean_squared_error: 34.7805 - val_loss: 15196.3789 - val_root_mean_squared_error: 123.2736
# Epoch 23/120
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 952.5010 - root_mean_squared_error: 30.6489 - val_loss: 15464.4277 - val_root_mean_squared_error: 124.3560
# Epoch 24/120
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 936.2856 - root_mean_squared_error: 30.4874 - val_loss: 24352.9629 - val_root_mean_squared_error: 156.0544
# Epoch 25/120
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1022.9723 - root_mean_squared_error: 31.9112 - val_loss: 19543.1602 - val_root_mean_squared_error: 139.7969
# Epoch 26/120
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1111.3936 - root_mean_squared_error: 33.1872 - val_loss: 22595.1465 - val_root_mean_squared_error: 150.3168
# Epoch 27/120
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1070.7004 - root_mean_squared_error: 32.5375 - val_loss: 11612.7920 - val_root_mean_squared_error: 107.7627
# Epoch 28/120
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1011.9144 - root_mean_squared_error: 31.7111 - val_loss: 17755.6855 - val_root_mean_squared_error: 133.2505
# Epoch 29/120
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1155.8457 - root_mean_squared_error: 33.9181 - val_loss: 16616.3008 - val_root_mean_squared_error: 128.9042
# Epoch 30/120
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1176.5476 - root_mean_squared_error: 34.2163 - val_loss: 21309.4707 - val_root_mean_squared_error: 145.9776
# Epoch 31/120
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1157.1089 - root_mean_squared_error: 33.7066 - val_loss: 21718.3047 - val_root_mean_squared_error: 147.3713
# Epoch 32/120
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1041.7797 - root_mean_squared_error: 32.1577 - val_loss: 17476.2207 - val_root_mean_squared_error: 132.1977
# Epoch 33/120
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1172.5183 - root_mean_squared_error: 34.2001 - val_loss: 19718.2852 - val_root_mean_squared_error: 140.4218
# Epoch 34/120
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 767.2842 - root_mean_squared_error: 27.2765 - val_loss: 19904.9453 - val_root_mean_squared_error: 141.0849
# Epoch 35/120
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1131.5245 - root_mean_squared_error: 33.4794 - val_loss: 20137.4219 - val_root_mean_squared_error: 141.9064
# Epoch 36/120
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 776.9331 - root_mean_squared_error: 27.6358 - val_loss: 21170.1992 - val_root_mean_squared_error: 145.4998
# Epoch 37/120
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 865.1718 - root_mean_squared_error: 29.2598 - val_loss: 19951.3828 - val_root_mean_squared_error: 141.2494
# Epoch 38/120
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 814.1707 - root_mean_squared_error: 28.3398 - val_loss: 17620.3398 - val_root_mean_squared_error: 132.7416
# Epoch 39/120
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 874.5146 - root_mean_squared_error: 29.5257 - val_loss: 18137.7539 - val_root_mean_squared_error: 134.6765
# Epoch 40/120
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 660.9237 - root_mean_squared_error: 25.5981 - val_loss: 17879.0352 - val_root_mean_squared_error: 133.7125
# Epoch 41/120
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 659.1180 - root_mean_squared_error: 25.5776 - val_loss: 17965.0293 - val_root_mean_squared_error: 134.0337
# Epoch 42/120
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 837.9702 - root_mean_squared_error: 28.8924 - val_loss: 22178.4863 - val_root_mean_squared_error: 148.9244
# Epoch 43/120
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1047.2744 - root_mean_squared_error: 32.2775 - val_loss: 22973.0352 - val_root_mean_squared_error: 151.5686
# Epoch 44/120
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1025.7440 - root_mean_squared_error: 31.8988 - val_loss: 19136.8711 - val_root_mean_squared_error: 138.3361
# Epoch 45/120
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 908.6867 - root_mean_squared_error: 30.0561 - val_loss: 13272.3516 - val_root_mean_squared_error: 115.2057
# Epoch 46/120
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 759.9793 - root_mean_squared_error: 27.3784 - val_loss: 21150.8125 - val_root_mean_squared_error: 145.4332
# Epoch 47/120
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1070.1049 - root_mean_squared_error: 32.6590 - val_loss: 16106.1367 - val_root_mean_squared_error: 126.9100
# Epoch 48/120
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 680.7208 - root_mean_squared_error: 25.9365 - val_loss: 17020.8477 - val_root_mean_squared_error: 130.4640
# Epoch 49/120
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 757.2131 - root_mean_squared_error: 27.4506 - val_loss: 16048.8740 - val_root_mean_squared_error: 126.6842
# Epoch 50/120
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 755.2992 - root_mean_squared_error: 27.4432 - val_loss: 12331.7686 - val_root_mean_squared_error: 111.0485
# Epoch 51/120
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 904.5766 - root_mean_squared_error: 29.7692 - val_loss: 18717.5410 - val_root_mean_squared_error: 136.8121
# Epoch 52/120
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1005.2559 - root_mean_squared_error: 31.6050 - val_loss: 13945.5215 - val_root_mean_squared_error: 118.0912
# Epoch 53/120
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 779.9341 - root_mean_squared_error: 27.6507 - val_loss: 17777.1816 - val_root_mean_squared_error: 133.3311
# Epoch 54/120
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1063.5438 - root_mean_squared_error: 32.5075 - val_loss: 8034.9639 - val_root_mean_squared_error: 89.6380
# Epoch 55/120
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 879.1657 - root_mean_squared_error: 29.5879 - val_loss: 17359.6777 - val_root_mean_squared_error: 131.7561
# Epoch 56/120
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 794.8332 - root_mean_squared_error: 27.9960 - val_loss: 17751.5996 - val_root_mean_squared_error: 133.2351
# Epoch 57/120
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1065.5874 - root_mean_squared_error: 32.5346 - val_loss: 14103.8535 - val_root_mean_squared_error: 118.7596
# Epoch 58/120
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1165.7678 - root_mean_squared_error: 33.9608 - val_loss: 14866.1836 - val_root_mean_squared_error: 121.9270
# Epoch 59/120
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1040.2465 - root_mean_squared_error: 32.2256 - val_loss: 33658.4297 - val_root_mean_squared_error: 183.4623
# Epoch 60/120
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 909.5629 - root_mean_squared_error: 29.9796 - val_loss: 20429.3848 - val_root_mean_squared_error: 142.9314
# Epoch 61/120
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 853.7297 - root_mean_squared_error: 29.1641 - val_loss: 20220.9961 - val_root_mean_squared_error: 142.2005
# Epoch 62/120
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1077.3158 - root_mean_squared_error: 32.6129 - val_loss: 17573.9531 - val_root_mean_squared_error: 132.5668
# Epoch 63/120
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 552.7872 - root_mean_squared_error: 23.2952 - val_loss: 14562.8662 - val_root_mean_squared_error: 120.6767
# Epoch 64/120
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 559.9987 - root_mean_squared_error: 23.5265 - val_loss: 11514.3643 - val_root_mean_squared_error: 107.3050
# Epoch 65/120
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1118.3607 - root_mean_squared_error: 33.2628 - val_loss: 17292.6582 - val_root_mean_squared_error: 131.5016
# Epoch 66/120
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 955.6457 - root_mean_squared_error: 30.8172 - val_loss: 33855.8164 - val_root_mean_squared_error: 183.9995
# Epoch 67/120
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 748.5853 - root_mean_squared_error: 27.2826 - val_loss: 27273.1699 - val_root_mean_squared_error: 165.1459
# Epoch 68/120
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1239.4777 - root_mean_squared_error: 34.7397 - val_loss: 26928.5918 - val_root_mean_squared_error: 164.0993
# Epoch 69/120
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 920.7510 - root_mean_squared_error: 30.2486 - val_loss: 15660.9199 - val_root_mean_squared_error: 125.1436
# Epoch 70/120
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1010.2725 - root_mean_squared_error: 31.4000 - val_loss: 14772.1738 - val_root_mean_squared_error: 121.5408
# Epoch 71/120
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1118.5911 - root_mean_squared_error: 33.0819 - val_loss: 21274.8340 - val_root_mean_squared_error: 145.8589
# Epoch 72/120
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 647.6130 - root_mean_squared_error: 25.2048 - val_loss: 14720.5254 - val_root_mean_squared_error: 121.3282
# Epoch 73/120
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 694.7014 - root_mean_squared_error: 26.2634 - val_loss: 13860.7197 - val_root_mean_squared_error: 117.7316
# Epoch 74/120
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 768.0436 - root_mean_squared_error: 27.6455 - val_loss: 10754.4170 - val_root_mean_squared_error: 103.7035
# Epoch 75/120
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 608.3107 - root_mean_squared_error: 24.3606 - val_loss: 14329.9326 - val_root_mean_squared_error: 119.7077
# Epoch 76/120
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 884.2287 - root_mean_squared_error: 29.6348 - val_loss: 7540.9614 - val_root_mean_squared_error: 86.8387
# Epoch 77/120
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1108.1273 - root_mean_squared_error: 33.2302 - val_loss: 9392.1699 - val_root_mean_squared_error: 96.9132
# Epoch 78/120
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 792.1859 - root_mean_squared_error: 28.0931 - val_loss: 10727.8867 - val_root_mean_squared_error: 103.5755
# Epoch 79/120
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 820.9630 - root_mean_squared_error: 28.6109 - val_loss: 19788.8828 - val_root_mean_squared_error: 140.6730
# Epoch 80/120
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 774.2786 - root_mean_squared_error: 27.8068 - val_loss: 10087.1250 - val_root_mean_squared_error: 100.4347
# Epoch 81/120
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 725.1920 - root_mean_squared_error: 26.6075 - val_loss: 23017.6309 - val_root_mean_squared_error: 151.7156
# Epoch 82/120
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 773.7456 - root_mean_squared_error: 27.7337 - val_loss: 19739.2617 - val_root_mean_squared_error: 140.4965
# Epoch 83/120
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 688.4637 - root_mean_squared_error: 26.0846 - val_loss: 12014.4102 - val_root_mean_squared_error: 109.6103
# Epoch 84/120
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 726.7491 - root_mean_squared_error: 26.8964 - val_loss: 9490.1084 - val_root_mean_squared_error: 97.4172
# Epoch 85/120
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 722.8486 - root_mean_squared_error: 26.7029 - val_loss: 21342.7070 - val_root_mean_squared_error: 146.0914
# Epoch 86/120
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 877.7314 - root_mean_squared_error: 29.5011 - val_loss: 19730.9316 - val_root_mean_squared_error: 140.4668
# Epoch 87/120
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 663.5132 - root_mean_squared_error: 25.6119 - val_loss: 14860.9365 - val_root_mean_squared_error: 121.9054
# Epoch 88/120
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 629.4175 - root_mean_squared_error: 25.0126 - val_loss: 19264.4668 - val_root_mean_squared_error: 138.7965
# Epoch 89/120
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 819.2424 - root_mean_squared_error: 28.0329 - val_loss: 20233.4219 - val_root_mean_squared_error: 142.2442
# Epoch 90/120
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 585.5178 - root_mean_squared_error: 24.1074 - val_loss: 23522.0547 - val_root_mean_squared_error: 153.3690
# Epoch 91/120
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 843.7784 - root_mean_squared_error: 29.0149 - val_loss: 20312.6328 - val_root_mean_squared_error: 142.5224
# Epoch 92/120
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 687.7485 - root_mean_squared_error: 26.1098 - val_loss: 12723.7070 - val_root_mean_squared_error: 112.7994
# Epoch 93/120
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1006.7004 - root_mean_squared_error: 31.6397 - val_loss: 23808.2168 - val_root_mean_squared_error: 154.2991
# Epoch 94/120
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 716.3813 - root_mean_squared_error: 26.7277 - val_loss: 28482.8340 - val_root_mean_squared_error: 168.7686
# Epoch 95/120
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 991.1176 - root_mean_squared_error: 31.3217 - val_loss: 30703.2812 - val_root_mean_squared_error: 175.2235
# Epoch 96/120
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 888.1475 - root_mean_squared_error: 29.7116 - val_loss: 28108.5020 - val_root_mean_squared_error: 167.6559
# Epoch 97/120
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 764.5128 - root_mean_squared_error: 27.6031 - val_loss: 26892.6211 - val_root_mean_squared_error: 163.9897
# Epoch 98/120
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 622.5953 - root_mean_squared_error: 24.8014 - val_loss: 23279.4785 - val_root_mean_squared_error: 152.5761
# Epoch 99/120
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 707.6100 - root_mean_squared_error: 26.5297 - val_loss: 33598.5039 - val_root_mean_squared_error: 183.2990
# Epoch 100/120
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1033.5378 - root_mean_squared_error: 31.6717 - val_loss: 32295.7559 - val_root_mean_squared_error: 179.7102
# Epoch 101/120
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 734.7854 - root_mean_squared_error: 26.9890 - val_loss: 33113.8516 - val_root_mean_squared_error: 181.9721
# Epoch 102/120
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 450.1814 - root_mean_squared_error: 20.9426 - val_loss: 31062.5742 - val_root_mean_squared_error: 176.2458
# Epoch 103/120
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 723.2802 - root_mean_squared_error: 26.6607 - val_loss: 30980.3945 - val_root_mean_squared_error: 176.0125
# Epoch 104/120
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 740.8795 - root_mean_squared_error: 26.8867 - val_loss: 28801.3848 - val_root_mean_squared_error: 169.7097
# Epoch 105/120
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 644.4188 - root_mean_squared_error: 25.2156 - val_loss: 25571.1152 - val_root_mean_squared_error: 159.9097
# Epoch 106/120
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 655.4768 - root_mean_squared_error: 25.5078 - val_loss: 26579.7422 - val_root_mean_squared_error: 163.0329
# Epoch 107/120
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 695.0123 - root_mean_squared_error: 25.9562 - val_loss: 16599.8066 - val_root_mean_squared_error: 128.8402
# Epoch 108/120
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 622.8965 - root_mean_squared_error: 24.9388 - val_loss: 23400.7871 - val_root_mean_squared_error: 152.9732
# Epoch 109/120
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1275.3064 - root_mean_squared_error: 35.1329 - val_loss: 23996.4434 - val_root_mean_squared_error: 154.9079
# Epoch 110/120
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 942.7219 - root_mean_squared_error: 30.1024 - val_loss: 23201.8184 - val_root_mean_squared_error: 152.3214
# Epoch 111/120
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 567.0449 - root_mean_squared_error: 23.6524 - val_loss: 24479.8613 - val_root_mean_squared_error: 156.4604
# Epoch 112/120
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 676.7935 - root_mean_squared_error: 25.9872 - val_loss: 21234.4883 - val_root_mean_squared_error: 145.7206
# Epoch 113/120
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 675.9706 - root_mean_squared_error: 25.7706 - val_loss: 34029.5586 - val_root_mean_squared_error: 184.4710
# Epoch 114/120
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 613.2778 - root_mean_squared_error: 24.6868 - val_loss: 29800.8066 - val_root_mean_squared_error: 172.6291
# Epoch 115/120
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 797.4584 - root_mean_squared_error: 27.7930 - val_loss: 28296.8066 - val_root_mean_squared_error: 168.2166
# Epoch 116/120
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 807.0271 - root_mean_squared_error: 28.3917 - val_loss: 28573.7070 - val_root_mean_squared_error: 169.0376
# Epoch 117/120
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 838.7922 - root_mean_squared_error: 28.8543 - val_loss: 39431.3789 - val_root_mean_squared_error: 198.5734
# Epoch 118/120
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1227.3429 - root_mean_squared_error: 34.9018 - val_loss: 35223.7578 - val_root_mean_squared_error: 187.6799
# Epoch 119/120
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 788.3918 - root_mean_squared_error: 27.9022 - val_loss: 39230.3633 - val_root_mean_squared_error: 198.0666
# Epoch 120/120
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 802.0892 - root_mean_squared_error: 28.2824 - val_loss: 29577.3906 - val_root_mean_squared_error: 171.9808
# Final train RMSE: 27.446496963500977
# Final validation RMSE: 171.9807891845703
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# R-squared: 0.5633005747179534

# %%
import tensorflow as tf
import matplotlib.pyplot as plt

# Define a function to compute gradients
def compute_gradients(input_data, model, target_index=0):
    input_tensor = tf.convert_to_tensor(input_data)
    with tf.GradientTape() as tape:
        tape.watch(input_tensor)
        predictions = model(input_tensor)
        target = predictions[:, target_index]  # Target the specific output
    gradients = tape.gradient(target, input_tensor)
    return gradients.numpy()

# Compute gradients for your test data
grads = compute_gradients(x_test, multivariate_lstm)


# Assuming `feature_names` is a list of column names corresponding to your features
# Example: feature_names = ["Feature1", "Feature2", ..., "FeatureN"]
feature_importance = np.sum(np.abs(grads), axis=1).mean(axis=0)  # Shape: (features,)

# Bar plot for feature importance with feature names
plt.figure(figsize=(12, 6))
plt.bar(feature_names_P1, feature_importance)
plt.xlabel('Features')
plt.ylabel('Gradient Magnitude (Aggregated)')
plt.title('Feature Importance for Model 3 (P1) Based on Gradients')
plt.xticks(rotation=45, ha='right')  # Rotate feature names for better readability
plt.tight_layout()  # Adjust layout to prevent overlap
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

y_pred = y_pred.flatten()
predictions_df = pd.DataFrame(y_pred, index=datetime_index, columns=['Predicted'])
y_test_df = pd.DataFrame(y_test, index=datetime_index, columns=['Actual'])
predictions_df = predictions_df.sort_index()
y_test_df = y_test_df.sort_index()

# Plotting y_actual vs y_pred
plt.figure(figsize=(12, 6))
plt.plot(datetime_index, y_test, label='Actual', marker='o')
plt.plot(y_test_df.index, predictions_df['Predicted'], label='Predicted', marker='x')
plt.title('Actual vs Predicted Values LSTM Model 3 on TEST - P1 Prediction')
plt.xlabel('DateTime')
plt.ylabel('Values')

# Rotate the x-axis labels for better visibility
plt.xticks(rotation=45)
plt.legend()
plt.grid()
plt.tight_layout()
plt.show()

# %%
df = pd.DataFrame(model_performance)
df
# Out:
#      Model Target  Percentage of Outliers Removed  Train RMSE   Test RMSE  \
# 0  Model 3     P0                            0.01   29.093815  105.213356
# 1  Model 3     P1                            0.01   27.446497  171.980789
#
#          R2
# 0  0.642904
# 1  0.563301
